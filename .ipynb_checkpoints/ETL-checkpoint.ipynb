# %% [markdown]
# # ETL
# ##### Extract, Transform, Load
# Get data from API/CSV/Other sources and store them in our own database

# %% [markdown]
# ### READING FROM CSV

# %%
import pandas as pd

file = "Resources/sample_data.csv"
# import os
# file = os.path.join("Resources", "sample_data.csv")
file_df = pd.read_csv(file)
file_df.head()

# ----------------------------------------------------------------------------------------
# for multiple csv files
year = ['2016', '2017', '2018', '2019']

df_list = {}
for y in year:
    file_name = f"Resources/san_francisco-censustracts-{y}-3-All-HourlyAggregate.csv"
    df_list[y] = pd.read_csv(file_name, usecols=['sourceid', 
                                                 'dstid', 
                                                 'hod', 
                                                 'mean_travel_time', 
                                                 'standard_deviation_travel_time'])
    
for y in year:
    print(df_list[y].head())
    print('------------------------------')

# %% [markdown]
# ### READING FROM API

# %%
import requests
import json

api_key = 'mFWPoeytiaD_-DrO5IL47Hvatuz9vN21N18vJn6isA-wIEPNWB5dZQN9L5mN5LYRn5SxFj9CxHHSYqtRc0N5kdsfJ_wsx_lw3NusiNHW36Drz5E44esWOqVd5ufvXXYx'
headers = {'Authorization': 'Bearer %s' % api_key}

url = 'https://api.yelp.com/v3/businesses/search'
params = {'term':'bookstore','location':'New York City'}

req = requests.get(url, params=params, headers=headers)

parsed = json.loads(req.text)

businesses = parsed["businesses"]

for business in businesses:
    print("Name:", business["name"])
    print("Rating:", business["rating"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")

    id = business["id"]

    url="https://api.yelp.com/v3/businesses/" + id + "/reviews"

    req = requests.get(url, headers=headers)

    parsed = json.loads(req.text)

    reviews = parsed["reviews"]

    print("--- Reviews ---")

    for review in reviews:
        print("User:", review["user"]["name"], "Rating:", review["rating"], "Review:", review["text"], "\n")
# Out:
# Name: McNally Jackson
# Rating: 4.5
# Address: 4 Fulton St New York, NY 10038
# Phone:
#
#
# --- Reviews ---
# User: Martina C. Rating: 5 Review: Yay! The seaport district/fidi finally have a good bookstore back! It just opened and it's wonderful. It's located inside Schermerhorn Row, the home of the...
#
# User: Ami Y. Rating: 4 Review: I really enjoyed visiting Mcnally Jackson here! The location feels homey and less crowded than the store in SoHo. The couches on the top floor is very...
#
# User: andrea p. Rating: 5 Review: I don't have enough good things to say about this bookstore /coffee shop.
# From the location to the interiors and the mood of the place to the wonderful...
#
# Name: Strand Bookstore
# Rating: 4.5
# Address: 828 Broadway New York, NY 10003
# Phone: +12124731452
#
#
# --- Reviews ---
# User: Coral B. Rating: 5 Review: When I was little my parents would bring me to the strand most weekends back then it looked very different then it does now.. I remember I was probably like...
#
# User: Grace T. Rating: 5 Review: SO. MANY. BOOKS. And I loved it!
#
# I love books and I, literally, can spend HOURS, inside bookstores. Whenever I'm in a new city, I love to check out one of...
#
# User: Dan H. Rating: 5 Review: I thought books were a dying medium, guess not since this place was nuts.
#
# I love a nice large bookstore and The Strand reminds me of what Barnes & Nobles...
#
# Name: McNally Jackson
# Rating: 4.5
# Address: 52 Prince St New York, NY 10012
# Phone: +12122741160
#
#
# --- Reviews ---
# User: Maria S. Rating: 5 Review: Quaint giant bookstore that looks tiny from the outside.
# That's the best way to describe this bookstore located in the middle of the street.
# It's filled...
#
# User: Betty W. Rating: 5 Review: I love this bookstore. On a rainy day, this place is a perfect getaway to sit down, order some coffee, and read a book while listening to the putter patter...
#
# User: Susan L. Rating: 5 Review: Tonight I attended a memorable author event; Mark Alan Stamaty (whose comics and other artwork you might be familiar with) gave a terrific talk.  Afterwards...
#
# Name: Greenlight Bookstore
# Rating: 4.5
# Address: 686 Fulton St Brooklyn, NY 11217
# Phone: +17182460200
#
#
# --- Reviews ---
# User: Michelle C. Rating: 5 Review: Greenlight has been one of my favorite small, independent bookstores since I first purchased my first book from them nearly 10 years ago. Over the years,...
#
# User: Carl B. Rating: 5 Review: I'm always delighted going to this excellent neighborhood bookstore and gathering space--never more so than this week to see my friend Alexander Tilney read...
#
# User: Dae D. Rating: 5 Review: The location in Ft. Greene has been my go-to bookstore since 2008. I love it so much. Greenlight not only has the hottest new books --they also house the...
#
# Name: Three Lives & Company
# Rating: 4.5
# Address: 154 W 10th St New York, NY 10014
# Phone: +12127412069
#
#
# --- Reviews ---
# User: Tricia M. Rating: 5 Review: We stumbled upon this beautiful little bookstore, while strolling through the Village. And so glad that I did! Part of the joy of the visit for me was in...
#
# User: James S. Rating: 5 Review: Favorite bookstore in all the boroughs. Curated selection, always something for me to buy. I judge a small bookstore by whether there is something for me to...
#
# User: Bonnie G. Rating: 5 Review: Today I cancelled my order on Amazon of a book and instead walked to Three Lives and supported this independent, cozy bookstore. Things you can't get on...
#
# Name: Astoria Bookshop
# Rating: 4.5
# Address: 31-29 31st St Astoria, NY 11102
# Phone: +17182782665
#
#
# --- Reviews ---
# User: Michael W. Rating: 5 Review: Awesome bookstore that is so charming.  When you walk in it really feels magical - it feels like one could literally stay there forever, with so many...
#
# User: Ilene -. Rating: 5 Review: Great independent bookstore. Small and busy. Owner is well knowledge on all books and friendly.
#
# User: Audrey L. Rating: 5 Review: This is the charming neighborhood bookshop everyone wishes were around the corner from their house. My advantage is that it's pretty much across the street...
#
# Name: Bluestockings
# Rating: 4.5
# Address: 172 Allen St New York, NY 10002
# Phone: +12127776028
#
#
# --- Reviews ---
# User: Mathilda A. Rating: 5 Review: This is one of those places I will probably visit every time I'm in NYC. This time I ended up just buying an Ursula Le Guin novel, but they have a wide...
#
# User: Kenny C. Rating: 4 Review: Man, this place is woke. I don't mean that sarcastically. Here, you'll find a ton of books written by people from historically marginalized backgrounds. And...
#
# User: Halina S. Rating: 2 Review: Couple good books among stacks of things that rich white kids and people with alternate lifestyles and appearance must think makes them unique (the thing...
#
# Name: WORD
# Rating: 4.5
# Address: 126 Franklin St Brooklyn, NY 11222
# Phone: +17183830096
#
#
# --- Reviews ---
# User: Layla R. Rating: 5 Review: Such a magical little place. Organized so you can find what you're looking for without any confusion. Kind staff and solid selection of books on display.
#
# User: Carolina S. Rating: 5 Review: I've always loved "WORD"! I'm a complete sucker for independent bookstores with little nooks and crannies. And how I can I not mention, Word is also in my...
#
# User: Gabriel T. Rating: 3 Review: Unfriendly, cramped and hot, limited selection of pretty much everything, not in any way supportive of local authors, and (this is unfortunate) I've seen...
#
# Name: The Mysterious Bookshop
# Rating: 4.5
# Address: 58 Warren St New York, NY 10007
# Phone: +12125871011
#
#
# --- Reviews ---
# User: Adrienne D. Rating: 5 Review: On the first day of autumn, curling up with a good mystery sounds like a perfect plan. A few weeks ago I visited The Mysterious Bookshop and marveled at the...
#
# User: Steph C. Rating: 3 Review: Last November, the Mystery Writers of America gave a prestigious lifetime achievement award to a novelist named Linda Fairstein, who you may know as the...
#
# User: Alicia B. Rating: 5 Review: Stumbled upon this gem as I was exploring the beautiful Tribeca./FiDi area! There's a cart outside with books for $2 .. a really good deal! Especially since...
#
# Name: Community Bookstore
# Rating: 4.0
# Address: 143 7th Ave Brooklyn, NY 11215
# Phone: +17187833075
#
#
# --- Reviews ---
# User: Nino K. Rating: 5 Review: I used to get all of my books here. People who work here are super nice, patient and helpful. It's a great place
# to spend a sunday afternoon.
#
# User: Gerard P. Rating: 2 Review: I have to agree with some of the other reviewers, i.e. the self-styled pretentiousness-cat included, although he's cute-can be a bit off-putting. The same...
#
# User: Zoya A. Rating: 4 Review: This is a cozy little bookstore in Park Slope. Books are original price (I would rather buy on Amazon because it is usually cheaper). But I have bought a...
#
# Name: Spoonbill & Sugartown Booksellers
# Rating: 3.5
# Address: 218 Bedford Ave Brooklyn, NY 11211
# Phone: +17183877322
#
#
# --- Reviews ---
# User: David R. Rating: 4 Review: Great bookstore. Not so much selection, but great curation of titles. Great if you don't exactly know what you want, not super great if you have a specific...
#
# User: Larissa M. Rating: 4 Review: Cute bookstore! It always interests me what types of books different places stock... I have absolutely no idea if Spoonbill's selection accurately reflects...
#
# User: Derrick S. Rating: 3 Review: This is an excellent local independent bookstore with an eclectic selection of interesting books. HOWEVER, the middle-aged gentleman at the counter (the...
#
# Name: Housing Works Bookstore Café
# Rating: 4.5
# Address: 126 Crosby St New York, NY 10012
# Phone: +12123343324
#
#
# --- Reviews ---
# User: Katherine K. Rating: 5 Review: I was on the hunt for a good bookstore and cafe to do work in for a while and saw this place online. Not only does this place have great vibes with a lot of...
#
# User: Sean S. Rating: 4 Review: This is such a special gem.  Hidden inside what looks like an old NYC library, is this used bookstore.
#
# Everything is donated, so all the sales proceeds go...
#
# User: Marian M. Rating: 5 Review: So beautiful and cozy big bookstore in New York! Love it, you can have coffee too while enjoying your reading!
#
# Tan linda y acogedora librería grande en...
#
# Name: McNally Jackson
# Rating: 5.0
# Address: 76 N 4th St Unit G Brooklyn, NY 11249
# Phone: +17183870115
# --- Reviews ---
# User: Joseph S. Rating: 5 Review: My first visit to McNally Jackson revealed a clean , and very organized bookstore. Sections were very well laid-out with varied selections. Prices seemed to...
#
# User: Tatiana f. Rating: 5 Review: I come here whenever I want to discover a new book to fall in love with. McNally Jackson is my favorite bookstore of all time. I used to go to the one in...
#
# User: Carl B. Rating: 5 Review: Beautiful space with a nice area upstairs for readings. One of my favorite spots on a street that's a murderer's row of standouts including Republic of Booza.
#
# Name: Book Thug Nation
# Rating: 4.0
# Address: 100 N 3rd St Brooklyn, NY 11211
# Phone:
#
#
# --- Reviews ---
# User: Noah M. Rating: 4 Review: Nice small one room bookstore in Williamsburg. It is well organized and easy to navigate. Close to a lot of good places so easy to take friends too.
#
# They...
#
# User: Nicole G. Rating: 5 Review: Best used bookstore in WB! Especially enjoyable when shopping alone in the afternoon. They also have used records and some zines available.
#
# User: Gigi A. Rating: 5 Review: I love this book shop and I make it a point to stop by whenever I'm in the area. They have many genres and unique books, even though the spot is kind of...
#
# Name: The Powerhouse Arena
# Rating: 4.0
# Address: 28 Adams St Brooklyn, NY 11201
# Phone: +17186663049
#
#
# --- Reviews ---
# User: Pritha R. Rating: 5 Review: I've been a supporter of the "Power" brand, starting by frequenting the Powerhouse Arena when it first opened in 2006.
#
# Dumbo in 2006 felt far more open...
#
# User: Nga C. Rating: 1 Review: The only thing that's impressive about this bookstore is their name. When I hear "Powerhouse" + "Arena", my immediate thinking is whooaaa, they must be an...
#
# User: Rachel L. Rating: 1 Review: I love bookstores. I'm a librarian and I love supporting literacy in anyway shape or form. Powerhouse really got under my skin when i looked at their sale...
#
# Name: Books Are Magic
# Rating: 4.5
# Address: 225 Smith St Brooklyn, NY 11231
# Phone: +17182462665
#
#
# --- Reviews ---
# User: Melissa M. Rating: 5 Review: Books are Magic is a wonderful little reading haven I'm Cobble Hill. It sets the standard for small, local bookstores.
#
# The books are so well curated. I...
#
# User: Tim L. Rating: 5 Review: As for a neighborhood bookstore goes, Books Are Magic has that perfect aesthetic, service, and selection that make it an immediate hit.
#
# In particular their...
#
# User: Neelakantan N. Rating: 5 Review: I go to a bookstore because I like browsing physical books. Its the same reason I go to market. I can touch and feel things and buy what I like. But...
#
# Name: Unnameable Books
# Rating: 4.0
# Address: 600 Vanderbilt Ave Brooklyn, NY 11238
# Phone: +17187891534
#
#
# --- Reviews ---
# User: Nino K. Rating: 5 Review: This bookstore has a lot of variety for being relatively small.  Even though my fired and I spent a LOT of time browsing in the store, we didn't feel rushed...
#
# User: Carla L. Rating: 5 Review: When we found out there was an independent bookstore in the area we headed on over to see what treasures we could find.
#
# Outside they had books on sale for...
#
# User: Janelle V. Rating: 4 Review: This independent bookstore is a book lover's dream. My friend recommended this shop to me and I'm so glad I paid them a visit! For a smaller shop, it's...
#
# Name: Molasses Books
# Rating: 4.5
# Address: 770 Hart St Brooklyn, NY 11237
# Phone:
#
#
# --- Reviews ---
# User: Ryan B. Rating: 5 Review: Such a sweet nook, to the point that writing them a 5 star review feels like I'm sharing a local secret that's meant to be kept.
#
# Great tunes, yummy coffee,...
#
# User: Elliott C. Rating: 5 Review: BOOKS + Beer!!! Came here for a friends book reading. It's a very cool space, but just make sure your group is small.  Also this place is super chill and...
#
# User: Nia T. Rating: 5 Review: This place was a great find. They sold mostly used books and there were dollar carts that were super exciting. I walked away with three books in hand.
#
# It...
#
# Name: Bookmark Shoppe
# Rating: 3.5
# Address: 8415 3rd Ave Brooklyn, NY 11209
# Phone: +17188335115
#
#
# --- Reviews ---
# User: Nancy C. Rating: 5 Review: This was our first visit to the Bookmark Shoppe and we were very impressed:) We went specifically for Daniel Paterna's book signing of his Feast of the...
#
# User: Hannah G. Rating: 5 Review: I visited bookmark shoppe last night for the first time and was very impressed (: I went for the book signing with Jessie james decker, one of my favorite...
#
# User: Fawn G. Rating: 3 Review: Cute neighborhood book shop in my neighborhood. I usually go to the Barnes and Noble on Court Street but I was in a crunch in obtaining the latest book for...
#
# Name: Better Read Than Dead
# Rating: 5.0
# Address: 867 Broadway Bushwick, NY 11206
# Phone: +13474705367
#
#
# --- Reviews ---
# User: Rebecca N. Rating: 5 Review: I was heading to a studio sale around the corner on a very hot day when the L train was down and I'd taken two buses and had had the kind of Brooklyn...
#
# User: Paula G. Rating: 5 Review: I would travel from NJ just to come back to this book store. Best selection I've come across between NJ, NY, and even CA which is ironic, since it's easily...
#
# User: Sarah S. Rating: 5 Review: This is the best little bookstore I've been to in NYC. Great selection, fair prices, and friendly and knowledgeable staff. I'll definitely be returning and...

# %% [markdown]
# ### STORE IN SQLITE

# %%
# TAKEN FROM: /10-Advanced-Data-Storage-and-Retrieval/1/Activities/10-Ins_SQL_Alchemy_Revisited/Solved/Alchemy_Annotated.ipynb

# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 

# Sets an object to utilize the default declarative base in SQL Alchemy
Base = declarative_base()

# Creates Classes which will serve as the anchor points for our Tables
class My_Class(Base):
    __tablename__ = 'my_table'
    id = Column(Integer, primary_key=True)
    name = Column(String(255))
    color = Column(String(255))
    num = Column(Integer)

# Creates a sqlite file and a connection to our DB
engine = create_engine("sqlite:///my_sqlite_file.sqlite")
conn = engine.connect()

# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
# Create (if not already in existence) the tables associated with our classes.
Base.metadata.create_all(engine)

# Use this to clear out the db
# ----------------------------------
# Base.metadata.drop_all(engine)

# Create a Session Object to Connect to DB
# ----------------------------------
# Session is a temporary binding to our DB
from sqlalchemy.orm import Session
session = Session(bind=engine)

# Create Instances of my class
class_instance_1 = My_Class(name='some_name', color='some_color', num=1)
class_instance_1 = My_Class(name="some_other_name", color="some_other_color", num=2)

# Add Records to the Appropriate DB
# ----------------------------------
# Use the SQL ALchemy methods to run simple "INSERT" statements using the classes and objects  
session.add(class_instance_1)
session.add(class_instance_2)
session.commit()

# Query the Tables / Also shown in section READING FROM SQLITE
# ----------------------------------
# Perform a simple query of the database
# my_list_of_rows = session.query(My_Class)
# for row in my_list_of_rows:
#     print(row.name)
#     print(row.color)
#     print(row.age)

# %% [markdown]
# ### STORE IN SQL

# %% [markdown]
# ### STORE IN MONGO DB

# %%
# TAKEN FROM: 12-Web-Scraping-and-Document-Databases/1/Activities/05-Ins_PyMongo/Solved/IntroToPymongo.py

# Module used to connect Python with MongoDb
import pymongo

# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.classDB

# Query all students
# Here, db.students refers to the collection 'classroom '
classroom = db.classroom.find()

# Iterate through each student in the collection
for student in classroom:
    print(student)

# Insert a document into the 'students' collection
db.classroom.insert_one(
    {
        'name': 'Ahmed',
        'row': 3,
        'favorite_python_library': 'Matplotlib',
        'hobbies': ['Running', 'Stargazing', 'Reading']
    }
)

# Update a document
db.classroom.update_one(
    {'name': 'Ahmed'},
    {'$set':
        {'row': 4}
     }
)

# Add an item to a document array
db.classroom.update_one(
    {'name': 'Ahmed'},
    {'$push':
        {'hobbies': 'Listening to country music'}
     }
)

# Delete a field from a document
db.classroom.update_one({'name': 'Ahmed'},
                        {'$unset':
                         {'gavecandy': ""}
                         }
                        )


# Delete a document from a collection
db.classroom.delete_one(
    {'name': 'Ahmed'}
)

# %% [markdown]
# ### READ FROM SQLITE

# %%
# TAKEN FROM: /10-Advanced-Data-Storage-and-Retrieval/1/Activities/04-Stu_ReadAllTheSQLs

from sqlalchemy import create_engine
# Path to sqlite
database_path = "../../my_file.sqlite"

# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{database_path}")

# Query All Records in the the Database
data = engine.execute("SELECT * FROM my_table")
for row in data:
    # returns a list 
    print(row)
    
# Store in pandas
import pandas as pd
conn = engine.connect()

# Query All Records in the the Database
data_df = pd.read_sql("SELECT * FROM my_table", conn)
print(data_df.row)

# Merging colums template
# combined_data = pd.merge(data_df_1, data_df_2, on="col_name", how="inner")

# %%
# ----------------------------------------------------------------------------------------
# Reading data using classes
# TAKEN FROM: /10-Advanced-Data-Storage-and-Retrieval/2/Activities/01-Ins_Basic_Querying/Solved/Ins_Basic_Querying.ipynb

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float

class BaseballPlayer(Base):
  __tablename__ = "player"
  player_id = Column(String, primary_key=True)
  birth_year = Column(Integer)
  birth_month = Column(Integer)
  birth_day = Column(Integer)
  birth_country = Column(String)
  birth_state = Column(String)
  birth_city = Column(String)
  name_first = Column(String)
  name_last = Column(String)
  name_given = Column(String)
  weight = Column(Integer)
  height = Column(Integer)
  bats = Column(String)
  throws = Column(String)
  debut = Column(String)
  final_game = Column(String)

from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Create Database Connection
engine = create_engine('sqlite:///../Resources/database.sqlite')
Base.metadata.create_all(engine)

from sqlalchemy.orm import Session
session = Session(bind=engine)

# Print all of the player names in the database
players = session.query(BaseballPlayer)
for player in players:
  print(player.name_given)

# Find the number of players from the USA
usa = session.query(BaseballPlayer).\
    filter(BaseballPlayer.birth_country == 'USA').count()
print("There are {} players from the USA".format(usa))

# Find those players who were born before 1990
born_before_1990 = session.query(BaseballPlayer).\
    filter(BaseballPlayer.birth_year < 1990).count()
    
print("{} players were born before 1990".format(born_before_1990))

# Find those players from the USA who were born after 1989
born_after_1989 = session.query(BaseballPlayer).\
    filter(BaseballPlayer.birth_year > 1989).filter(BaseballPlayer.birth_country == "USA").\
    count()
print("{} USA players were born after 1989".format(born_after_1989))

# %%
# ----------------------------------------------------------------------------------------
# Reading data using reflection
# TAKEN FROM: /10-Advanced-Data-Storage-and-Retrieval/2/Activities/06-Stu_ReflectingOnSQL/Solved/Stu_Reflection.ipynb

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///../Resources/demographics.sqlite")

# Declare a Base using `automap_base()`
Base = automap_base()

# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# Print all of the classes mapped to the Base
Base.classes.keys()

# Assign the demographics class to a variable called `Demographics`
Demographics = Base.classes.demographics

# Create a session
session = Session(engine)

# Use the session to query Demographics table and display the first 5 locations
for row in session.query(Demographics, Demographics.location).limit(5).all():
    print(row)

# BONUS: Query and print the number of unique Locations
# Hints: Look into counting and grouping operations in SQLAlchemy
locations = session.query(Demographics).group_by(Demographics.location).count()
print(locations)

# %%
# ----------------------------------------------------------------------------------------
# how to get table colums
# TAKEN FROM: /10-Advanced-Data-Storage-and-Retrieval/2/Activities/09-Par_EmojiPlotting/Solved/Stu_Plotting.ipynb

import pandas as pd

# Import SQLAlchemy `automap` and other dependencies here
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# Create an engine for the `emoji.sqlite` database
engine = create_engine("sqlite:///../Resources/emoji.sqlite", echo=False)

# Use the Inspector to explore the database and print the table names
inspector = inspect(engine)
inspector.get_table_names()

# Use Inspector to print the column names and types
columns = inspector.get_columns('emoji')
for c in columns:
    print(c['name'], c["type"])
    
    # Use `engine.execute` to select and display the first 10 rows from the emoji table
engine.execute('SELECT * FROM emoji LIMIT 10').fetchall()
